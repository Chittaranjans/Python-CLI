# %%
pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/29/d4/1244ab8edf173a10fd601f7e13b9566c1b525c4f365d6bee918e68381889/pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/4c/79/73735a6a5dad6059c085f240a4e74c9270feccd2bc66e4d31b5ca01d329c/numpy-2.1.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading numpy-2.1.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.7 kB ? eta -:--:--
#      -------------------------------------- 59.7/59.7 kB 785.8 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sahoo\dev\python-cli\virtual\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/11/c3/005fcca25ce078d2cc29fd559379817424e94885510568bc1bc53d7d5846/pytz-2024.2-py2.py3-none-any.whl.metadata
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/a6/ab/7e5f53c3b9d14972843a647d8d7a853969a58aecc7559cb3267302c94774/tzdata-2024.2-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sahoo\dev\python-cli\virtual\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 2.2 MB/s eta 0:00:06
#     --------------------------------------- 0.2/11.5 MB 2.4 MB/s eta 0:00:05
#     --------------------------------------- 0.2/11.5 MB 2.4 MB/s eta 0:00:05
#     --------------------------------------- 0.2/11.5 MB 2.4 MB/s eta 0:00:05
#     --------------------------------------- 0.3/11.5 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/11.5 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/11.5 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.5 MB 1.4 MB/s eta 0:00:08
#    -- ------------------------------------- 0.7/11.5 MB 1.6 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.5 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.5 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.5 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.1/11.5 MB 1.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.2/11.5 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.4/11.5 MB 2.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.5 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.5 MB 2.3 MB/s eta 0:00:05
#    ------ --------------------------------- 1.9/11.5 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.0/11.5 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.2/11.5 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/11.5 MB 2.3 MB/s eta 0:00:04
#    -------- ------------------------------- 2.5/11.5 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.7/11.5 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.5 MB 2.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/11.5 MB 2.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/11.5 MB 2.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/11.5 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/11.5 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 2.7 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.5 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 4.0/11.5 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.5 MB 2.8 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 2.9 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 2.9 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 2.9 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/11.5 MB 2.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.6/11.5 MB 2.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.5 MB 2.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 2.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 2.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.1/11.5 MB 2.7 MB/s eta 0:00:03
#    ------------------ --------------------- 5.4/11.5 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.5 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.7/11.5 MB 2.8 MB/s eta 0:00:03
#    -------------------- ------------------- 5.9/11.5 MB 2.8 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.5 MB 2.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.5 MB 3.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.2/11.5 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.5/11.5 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.8/11.5 MB 3.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.5 MB 3.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.3/11.5 MB 3.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.5 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.1/11.5 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 3.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 4.3 MB/s eta 0:00:00
# Downloading numpy-2.1.2-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 15.0 MB/s eta 0:00:01
#    -- ------------------------------------- 0.9/12.6 MB 11.8 MB/s eta 0:00:01
#    -- ------------------------------------- 0.9/12.6 MB 11.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.2/12.6 MB 6.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.6 MB 7.4 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.6 MB 7.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.6 MB 8.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.3/12.6 MB 9.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.8/12.6 MB 9.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.6 MB 9.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.8/12.6 MB 10.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.3/12.6 MB 9.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.3/12.6 MB 9.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.3/12.6 MB 9.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.4/12.6 MB 7.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.6 MB 7.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.6 MB 7.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.6 MB 7.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.6 MB 7.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.6 MB 7.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.6 MB 7.4 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.6 MB 6.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.7/12.6 MB 6.4 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 6.1 MB/s eta 0:00:01
#    --------------------- ------------------ 6.9/12.6 MB 6.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.6 MB 5.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.6 MB 5.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.7/12.6 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.6/12.6 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.1/12.6 MB 6.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.6 MB 6.0 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 6.1 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.6 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 6.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.6 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.7/12.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 6.2 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ---------------------------------------- 0.0/508.0 kB ? eta -:--:--
#    --------------------------------------- 508.0/508.0 kB 16.1 MB/s eta 0:00:00
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.6 kB ? eta -:--:--
#    --------------------------------------- 346.6/346.6 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.1.2 pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
p = pd.read_csv("Real Estate Data V21.csv")
p
# Out:
#                                                     Name  \
# 0                                       Casagrand ECR 14
# 1                  Ramanathan Nagar, Pozhichalur,Chennai
# 2                                            DAC Prapthi
# 3                Naveenilaya,Chepauk, Triplicane,Chennai
# 4                               VGN Spring Field Phase 1
# ...                                                  ...
# 14523      Krishna Park Extension, Tilak Nagar,New Delhi
# 14524                   Rawta, Jaffarpur Kalan,New Delhi
# 14525                Rani Garden, Geeta Colony,New Delhi
# 14526  Lig flat rohini,Sector 16E, Sector 16 Rohini,N...
# 14527               Sector 3B, Sector 3 Rohini,New Delhi
#
#                                           Property Title     Price  \
# 0      4 BHK Flat for sale in Kanathur Reddikuppam, C...  ₹1.99 Cr
# 1      10 BHK Independent House for sale in Pozhichal...  ₹2.25 Cr
# 2          3 BHK Flat for sale in West Tambaram, Chennai   ₹1.0 Cr
# 3      7 BHK Independent House for sale in Triplicane...  ₹3.33 Cr
# 4                  2 BHK Flat for sale in Avadi, Chennai   ₹48.0 L
# ...                                                  ...       ...
# 14523      2 BHK Flat for sale in Tilak Nagar, New Delhi   ₹40.0 L
# 14524  1 BHK Independent House for sale in Jaffarpur ...   ₹14.0 L
# 14525     1 BHK Flat for sale in Geeta Colony, New Delhi   ₹30.0 L
# 14526  3 BHK Flat for sale in Sector 16 Rohini, New D...   ₹60.0 L
# 14527  1 RK Independent House for sale in Sector 3 Ro...   ₹55.0 L
#
#                                                 Location  Total_Area  \
# 0                          Kanathur Reddikuppam, Chennai        2583
# 1                  Ramanathan Nagar, Pozhichalur,Chennai        7000
# 2               Kasthuribai Nagar, West Tambaram,Chennai        1320
# 3                Naveenilaya,Chepauk, Triplicane,Chennai        4250
# 4                                         Avadi, Chennai         960
# ...                                                  ...         ...
# 14523      Krishna Park Extension, Tilak Nagar,New Delhi        1053
# 14524                   Rawta, Jaffarpur Kalan,New Delhi         472
# 14525                Rani Garden, Geeta Colony,New Delhi         378
# 14526  Lig flat rohini,Sector 16E, Sector 16 Rohini,N...         700
# 14527               Sector 3B, Sector 3 Rohini,New Delhi         344
#
#        Price_per_SQFT                                        Description  \
# 0              7700.0  Best 4 BHK Apartment for modern-day lifestyle ...
# 1              3210.0  Looking for a 10 BHK Independent House for sal...
# 2              7580.0  Property for sale in Tambaram, Chennai. This 3...
# 3              7840.0  Entire Building for sale with 7 units of singl...
# 4              5000.0  Property for sale in Avadi, Chennai. This 2 BH...
# ...               ...                                                ...
# 14523          3800.0  Looking for a good 2 BHK Apartment in Tilak Na...
# 14524          2970.0  1 BHK Independent House for sale in Jaffarpur ...
# 14525          7940.0  Property for sale in Geeta Colony, Delhi. This...
# 14526          8570.0  Check out this 3 BHK Apartment for sale in Roh...
# 14527         15990.0  This is an independent DDA house(in raw condit...
#
#        Baths Balcony
# 0          4     Yes
# 1          6     Yes
# 2          3      No
# 3          5     Yes
# 4          3     Yes
# ...      ...     ...
# 14523      3     Yes
# 14524      2     Yes
# 14525      1     Yes
# 14526      2     Yes
# 14527      1     Yes
#
# [14528 rows x 9 columns]

# %%
list(p.columns)
# Out:
# ['Name',
#  'Property Title',
#  'Price',
#  'Location',
#  'Total_Area',
#  'Price_per_SQFT',
#  'Description',
#  'Baths',
#  'Balcony']

# %%
highest_price = p['Price'].max()
print(f"The highest price is: ${highest_price:}")
# Out:
# The highest price is: $₹99.99 L

# %%
price = p['Price']
price
# Out:
# 0        ₹1.99 Cr
# 1        ₹2.25 Cr
# 2         ₹1.0 Cr
# 3        ₹3.33 Cr
# 4         ₹48.0 L
#            ...
# 14523     ₹40.0 L
# 14524     ₹14.0 L
# 14525     ₹30.0 L
# 14526     ₹60.0 L
# 14527     ₹55.0 L
# Name: Price, Length: 14528, dtype: object

# %%
top_values = []
for _, row in p.iterrows():
    value = row['Price']  # Replace 'Value' with your actual column name
    top_values.append(value)

# Sort the values in descending order
top_values.sort(reverse=True)

# Get the top 10 values
top_10_highest = top_values[:10]

print("Top 10 Highest Values:")
print(top_10_highest)
# Out:
# Top 10 Highest Values:
# ['₹99.99 L', '₹99.99 L', '₹99.95 L', '₹99.5 L', '₹99.5 L', '₹99.32 L', '₹99.0 L', '₹99.0 L', '₹99.0 L', '₹99.0 L']

# %%
top_10_highest = p['Price'].nlargest(10)
print("Top 10 Highest Values:")
print(top_10_highest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 top_10_highest = p['Price'].nlargest(10)
#       2 print("Top 10 Highest Values:")
#       3 print(top_10_highest)
#
# File ~\dev\python-cli\virtual\Lib\site-packages\pandas\core\series.py:4252, in Series.nlargest(self, n, keep)
#    4154 def nlargest(
#    4155     self, n: int = 5, keep: Literal["first", "last", "all"] = "first"
#    4156 ) -> Series:
#    4157     """
#    4158     Return the largest `n` elements.
#    4159
#    (...)
#    4250     dtype: int64
#    4251     """
# -> 4252     return selectn.SelectNSeries(self, n=n, keep=keep).nlargest()
#
# File ~\dev\python-cli\virtual\Lib\site-packages\pandas\core\methods\selectn.py:57, in SelectN.nlargest(self)
#      55 @final
#      56 def nlargest(self):
# ---> 57     return self.compute("nlargest")
#
# File ~\dev\python-cli\virtual\Lib\site-packages\pandas\core\methods\selectn.py:96, in SelectNSeries.compute(self, method)
#      94 dtype = self.obj.dtype
#      95 if not self.is_valid_dtype_n_method(dtype):
# ---> 96     raise TypeError(f"Cannot use method '{method}' with dtype {dtype}")
#      98 if n <= 0:
#      99     return self.obj[[]]
#
# TypeError: Cannot use method 'nlargest' with dtype object

# %%
p['Price'] = pd.to_numeric(p['Price'], errors='coerce')

# Now you can use nlargest()
top_10_highest = p['Price'].nlargest(10)

print("Top 10 Highest Values:")
print(top_10_highest)
# Out:
# Top 10 Highest Values:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: Price, dtype: float64

# %%
max_value = max(price)
print(max_value)
# Out:
# ₹99.99 L

# %%
price_per = p['Price_per_SQFT']
price_per
# Out:
# 0         7700.0
# 1         3210.0
# 2         7580.0
# 3         7840.0
# 4         5000.0
#           ...
# 14523     3800.0
# 14524     2970.0
# 14525     7940.0
# 14526     8570.0
# 14527    15990.0
# Name: Price_per_SQFT, Length: 14528, dtype: float64

# %%
max_value_perprice = max(price_per)
max_line = len(price_per)
print(max_line) 
print(max_value_perprice)
# Out:
# 14528
# 999000.0

# %%
import folium
m = folium.Map([45.35, -121.6972], zoom_start=12)

folium.Marker(
    location=[45.3288, -121.6625],
    tooltip="Click me!",
    popup="Mt. Hood Meadows",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    tooltip="Click me!",
    popup="Timberline Lodge",
    icon=folium.Icon(color="green"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c027123c996e1125132f13c533a380cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c027123c996e1125132f13c533a380cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c027123c996e1125132f13c533a380cf = L.map(
#                 &quot;map_c027123c996e1125132f13c533a380cf&quot;,
#                 {
#                     center: [45.35, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_923450a009bbd79c7026979a92c53226 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_923450a009bbd79c7026979a92c53226.addTo(map_c027123c996e1125132f13c533a380cf);
#
#
#             var marker_100e0cb09e417e6cfb12de3abee15a1f = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_c027123c996e1125132f13c533a380cf);
#
#
#             var icon_4e0da59d25cedff5a2e623b9db72ffb4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_100e0cb09e417e6cfb12de3abee15a1f.setIcon(icon_4e0da59d25cedff5a2e623b9db72ffb4);
#
#
#         var popup_934c44c6f0e1e2ea0fdeb7fe7914fb61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_210dd6004d5b5d6d252167c45f3012b9 = $(`&lt;div id=&quot;html_210dd6004d5b5d6d252167c45f3012b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mt. Hood Meadows&lt;/div&gt;`)[0];
#                 popup_934c44c6f0e1e2ea0fdeb7fe7914fb61.setContent(html_210dd6004d5b5d6d252167c45f3012b9);
#
#
#
#         marker_100e0cb09e417e6cfb12de3abee15a1f.bindPopup(popup_934c44c6f0e1e2ea0fdeb7fe7914fb61)
#         ;
#
#
#
#
#             marker_100e0cb09e417e6cfb12de3abee15a1f.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ed4c31ba0b8114c2d0886807868b2e1 = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_c027123c996e1125132f13c533a380cf);
#
#
#             var icon_581432b41e423a2c57b9875c60200a7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ed4c31ba0b8114c2d0886807868b2e1.setIcon(icon_581432b41e423a2c57b9875c60200a7b);
#
#
#         var popup_dc976c1676e2d28787a8762294461bdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a60d8896fede7ebdd04cf19e3c962e67 = $(`&lt;div id=&quot;html_a60d8896fede7ebdd04cf19e3c962e67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#                 popup_dc976c1676e2d28787a8762294461bdb.setContent(html_a60d8896fede7ebdd04cf19e3c962e67);
#
#
#
#         marker_7ed4c31ba0b8114c2d0886807868b2e1.bindPopup(popup_dc976c1676e2d28787a8762294461bdb)
#         ;
#
#
#
#
#             marker_7ed4c31ba0b8114c2d0886807868b2e1.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !pip install be
